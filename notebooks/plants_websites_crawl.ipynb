# %%
import asyncio
import io
import os
import time
from urllib.parse import urljoin, urlparse, urlunparse

import aiohttp
import nest_asyncio
import pandas as pd
import PyPDF2
from bs4 import BeautifulSoup

nest_asyncio.apply() # for running async code in notebook

# %%
# Define cert->keywords mapping
CERT_KEYWORDS = {
    "ASC Cert": [
        "ASC", "A.S.C.", "Aquaculture Stewardship Council",
    ],
    "BAP Cert": [
        "BAP", "Best Aquaculture Practices", "Global Seafood Alliance"
    ],
    "FOS Cert": [
        "Friend of the Sea", "FOS", "WSO", "World Sustainability Organization"
    ],
    "FIP Cert": [
        "FIP", "Fisheries Improvement Project"
    ],
    "MarinTrust Cert": [
        "Marin Trust"
    ]
}

# %%
def extract_text_from_pdf(pdf_content: bytes) -> str:
    """
    Extract and concatenate text from all pages of a PDF document.
    
    Args:
        pdf_content (bytes): Raw PDF file content as bytes
        
    Returns:
        str: Extracted text from all PDF pages, converted to lowercase
        
    Notes:
        - Uses PyPDF2 to parse PDF and extract text page by page
        - Silently handles PDF parsing errors by printing error message
        - Empty/unparseable pages are skipped
        - All extracted text is concatenated into a single string
    """
    text = ""
    try:
        # Create in-memory file object from PDF bytes
        with io.BytesIO(pdf_content) as pdf_file:
            # Initialize PDF reader
            reader = PyPDF2.PdfReader(pdf_file)
            
            # Extract text from each page
            for page in reader.pages:
                page_text = page.extract_text()
                # Only append if page contained text
                if page_text:
                    text += page_text
                    
    except Exception as e:
        # Log any PDF parsing errors
        print(f"[PDF ERROR] {e}")
        
    return text.lower()

# %%
def is_same_domain(base_url: str, new_url: str) -> bool:
    """Returns True if new_url is on the same domain (or subdomain) as base_url."""
    base_domain = urlparse(base_url).netloc
    check_domain = urlparse(new_url).netloc
    # A loose check: ensure the base domain is a substring of check_domain
    # e.g. base: "example.com", check: "sub.example.com" => True
    return base_domain in check_domain

# %%
def normalize_url(url: str) -> str:
    """Remove fragment, remove trailing slash from path, return normalized URL."""
    parsed = urlparse(url)

    # Drop the fragment entirely
    parsed = parsed._replace(fragment="")

    # Remove trailing slash in path
    path = parsed.path
    if path.endswith("/") and len(path) > 1:
        path = path[:-1]
    parsed = parsed._replace(path=path)

    # Rebuild into a string
    cleaned_url = urlunparse(parsed)
    return cleaned_url

# %%
async def crawl_for_keywords_async(
    session: aiohttp.ClientSession,
    seed_url: str,
    cert_keywords: dict,
    max_depth: int = 2,
    limit_pages: int = 50,
    politeness_delay: float = 0.5
) -> dict:
    """
    Asynchronously crawl a website starting from seed_url, searching for certification keywords.
    Uses breadth-first search (BFS) to explore links up to max_depth away from the seed URL.
    
    Args:
        session: aiohttp client session for making HTTP requests
        seed_url: Starting URL to begin crawl from
        cert_keywords: Dictionary mapping certification columns to lists of keywords
        max_depth: Maximum link depth to explore from seed_url (default: 2)
        limit_pages: Maximum total pages to fetch across all depths (default: 50)
        politeness_delay: Seconds to wait between requests to same domain (default: 0.5)
    
    Returns:
        Dictionary mapping certification columns to sets of URLs where keywords were found
    """
    # Track URLs found for each certification type
    found_urls_by_cert = {col: set() for col in cert_keywords.keys()}
    
    # Track visited URLs to avoid cycles
    visited = set()
    
    # Queue for BFS traversal - each item is (url, depth) tuple
    queue = asyncio.Queue()
    await queue.put((seed_url, 0))

    pages_crawled = 0
    
    while not queue.empty():
        current_url, depth = await queue.get()
        queue.task_done()

        # Skip if we've exceeded max depth
        if depth > max_depth:
            continue
        
        # Skip if already visited this URL
        if current_url in visited:
            continue
        visited.add(current_url)

        # Only crawl URLs on same domain as seed
        if not is_same_domain(seed_url, current_url):
            continue

        # Stop if we've hit the page limit
        if pages_crawled >= limit_pages:
            break

        # Respect crawl delay
        await asyncio.sleep(politeness_delay)

        try:
            async with session.get(current_url, timeout=10) as resp:
                if resp.status != 200:
                    continue
                pages_crawled += 1
                
                content_type = resp.headers.get('Content-Type', '').lower()
                
                if 'pdf' in content_type:
                    # For PDFs: download bytes, extract text, check for keywords
                    pdf_bytes = await resp.read()
                    pdf_text = extract_text_from_pdf(pdf_bytes)
                    for cert_col, kws in cert_keywords.items():
                        for kw in kws:
                            if kw.lower() in pdf_text:
                                normalized = normalize_url(current_url) 
                                found_urls_by_cert[cert_col].add(normalized)
                
                elif 'html' in content_type:
                    # For HTML: parse content, extract text, check for keywords
                    html = await resp.text(errors='ignore')
                    soup = BeautifulSoup(html, 'html.parser')
                    page_text = soup.get_text(separator=' ').lower()

                    # Check each certification's keywords against page text
                    for cert_col, kws in cert_keywords.items():
                        for kw in kws:
                            if kw.lower() in page_text:
                                normalized = normalize_url(current_url)
                                found_urls_by_cert[cert_col].add(normalized)

                    # If not at max depth, add all links to queue
                    if depth < max_depth:
                        for link_tag in soup.find_all("a", href=True):
                            child_url = urljoin(current_url, link_tag['href'])
                            if child_url not in visited:
                                await queue.put((child_url, depth + 1))
                else:
                    # Skip non-HTML/PDF content types
                    pass

        except Exception as e:
            print(f"[ERROR] {current_url} => {e}")
            continue

    return found_urls_by_cert

# %%
async def process_df_with_sites(df_with_sites: pd.DataFrame) -> pd.DataFrame:
    """
    Process each website in the DataFrame to find certification information.
    
    Creates an aiohttp session and crawls each company website to search for 
    certification-related keywords. Updates the certification columns in the DataFrame
    with any found URLs containing certification information.

    Args:
        df_with_sites: DataFrame containing company websites and certification columns
        
    Returns:
        Updated DataFrame with certification URLs added to relevant columns
    """
    
    async with aiohttp.ClientSession() as session:
        for idx, row in df_with_sites.iterrows():
            seed_url = row["Company website"]
            
            # Ensure URL has protocol prefix
            if not seed_url.startswith("http"):
                seed_url = "http://" + seed_url
            
            print(f"\nCrawling: {seed_url} (index: {idx})")
            
            # Perform breadth-first crawl of the site looking for certification keywords
            # Returns dict mapping certification columns to sets of URLs containing matches
            found_by_cert = await crawl_for_keywords_async(
                session=session,
                seed_url=seed_url,
                cert_keywords=CERT_KEYWORDS,
                max_depth=2,        # How many links deep to crawl
                limit_pages=50,     # Maximum number of pages to crawl
                politeness_delay=0.5 # Delay between requests in seconds
            )
            
            # Update DataFrame with any newly found certification URLs
            for cert_col, found_urls in found_by_cert.items():
                if found_urls:
                    # Get existing URLs for this certification, handling NaN values
                    existing_val = row.get(cert_col, "")
                    if not isinstance(existing_val, str):
                        existing_val = ""
                    
                    # Convert semicolon-separated string to set of URLs
                    old_urls = set(u.strip() for u in existing_val.split(";") if u.strip())
                    
                    # Combine existing and newly found URLs, removing duplicates
                    merged = old_urls.union(found_urls)
                    
                    # Update DataFrame with sorted, semicolon-separated URL string
                    new_val = ";".join(sorted(merged))
                    df_with_sites.at[idx, cert_col] = new_val
    
    return df_with_sites

# %%
async def main():
    # Load company data from Google Sheets into DataFrame
    df_all = pd.read_csv("https://docs.google.com/spreadsheets/d/1jJA1pYMDPiBEXFGnT3LXtjEHC7Ya4W4GhG-D8uhCplE/export?format=csv")
    
    # Initialize and standardize certification columns as empty strings
    # This prevents dtype warnings and ensures consistent handling
    for cert_col in CERT_KEYWORDS.keys():
        if cert_col not in df_all.columns:
            df_all[cert_col] = ""
        df_all[cert_col] = df_all[cert_col].fillna("").astype(str)
    
    # Extract subset of companies that have website URLs
    # Create clean copy with stripped website URLs
    df_with_sites = df_all.dropna(subset=["Company website"]).copy()
    df_with_sites["Company website"] = df_with_sites["Company website"].str.strip()
    
    # Crawl each company website asynchronously to find certification pages
    # Track and display total execution time
    start_time = time.time()
    updated_df_with_sites = asyncio.run(process_df_with_sites(df_with_sites))
    end_time = time.time()
    print(f"\nCrawling complete. Elapsed time: {end_time - start_time:.2f} seconds.")
    
    # Update main DataFrame with any newly discovered certification URLs
    # Preserves original row indices while updating only certification columns
    for idx, row in updated_df_with_sites.iterrows():
        df_all.loc[idx, CERT_KEYWORDS.keys()] = row[list(CERT_KEYWORDS.keys())]
    
    # Save results to CSV, appending timestamp if file already exists
    # This prevents overwriting previous results
    output_file = "plants_websites_crawled.csv"
    if os.path.exists(output_file):
        timestamp = int(time.time())
        output_file = f"plants_updated_{timestamp}.csv"
    df_all.to_csv(output_file, index=False)
    print("Results saved to CSV file")

    df_all

# %%
if __name__ == "__main__":
    asyncio.run(main())
# Out:
# Crawling: https://bhpimpex.ca/ (index: 1)
#
# Crawling: https://abideenfishmeal.com/en/index.html (index: 2)
#
# Crawling: https://fishmeal.co/ (index: 4)
#
# Crawling: https://www.nublend.com.au/index.php/products (index: 5)
#
# Crawling: https://www.comeausea.com/facilities (index: 7)
#
# Crawling: https://ditp.sec.gouv.sn/sites/default/files/docs/Liste%20des%20%C3%A9tablissements%20agr%C3%A9%C3%A9s%20%C3%A0%20l%27exportation%20au%2031%20d%C3%A9cembre%202022%20.pdf (index: 8)
#
# Crawling: https://www.csfproteins.com.au (index: 9)
#
# Crawling: http://www.gdhxgf.com/en/gsjj_en.html (index: 11)
#
# Crawling: https://novosana.nl/ (index: 12)
#
# Crawling: https://pmtcr.com/english/oil.htm (index: 13)
#
# Crawling: https://www.akerbiomarine.com/ (index: 14)
#
# Crawling: http://valofish.fr (index: 15)
#
# Crawling: https://matchory.com/supplier/golden-lead-import-and-export-trade (index: 16)
#
# Crawling: https://nessimtrading.com/nessim-fisheries/ (index: 17)
#
# Crawling: https://iceberg2.ge/index.php?action_skin_change=yes&skin_name=IB2ENG#product (index: 18)
# [ERROR] https://iceberg2.ge/index.php?action_skin_change=yes&skin_name=IB2ENG#product => Cannot connect to host iceberg2.ge:443 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: http://www.olvea.com/fish-oils (index: 19)
# [ERROR] https://www.olvea.com/wp-content/uploads/2020/10/OLVEAct-Now-Corporate-social-responsibility-Performance-report-2019-2020.pdf =>
#
# Crawling: https://www.tradeford.com/ec474992/fish-meal_p767255.html (index: 20)
#
# Crawling: https://ditp.sec.gouv.sn/sites/default/files/docs/Liste%20des%20%C3%A9tablissements%20agr%C3%A9%C3%A9s%20%C3%A0%20l%27exportation%20au%2031%20d%C3%A9cembre%202022%20.pdf (index: 22)
#
# Crawling: http://www.enzaq.com/ (index: 23)
#
# Crawling: https://manabitadecomercio.com/ (index: 26)
# [ERROR] https://manabitadecomercio.com/ => Cannot connect to host manabitadecomercio.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1018)')]
#
# Crawling: https://www.akerbiomarine.com/ (index: 30)
#
# Crawling: http://www.hx-aquatic.com/ (index: 31)
#
# Crawling: https://www.cndedany.com/ (index: 32)
#
# Crawling: https://www.bioceval.de/en/ouroffering/fish-meal/ (index: 33)
#
# Crawling: https://lamotte-oils.de/en/product/fish-oils/ (index: 34)
#
# Crawling: https://www.brim.is/en/about/processing (index: 36)
#
# Crawling: http://eng.huahengbio.com/ (index: 37)
# [ERROR] http://eng.huahengbio.com/ =>
#
# Crawling: http://www.sinomega-biotech.com/?lan=en_2 (index: 38)
#
# Crawling: http://www.high-fortune.cn/index.html (index: 39)
#
# Crawling: http://www.isfelag.is (index: 40)
#
# Crawling: https://lvf.is/vinnsla/ (index: 41)
#
# Crawling: https://sanarawa.com/ (index: 42)
#
# Crawling: http://www.huatai-biopharm.com/htweb/page.asp?bigclass=5 (index: 43)
#
# Crawling: https://www.djoola.com/en/corporate/companies/details/2734 (index: 44)
#
# Crawling: https://novosana.nl/ (index: 46)
#
# Crawling: https://zhuosidaer.en.ecplaza.net/ (index: 48)
#
# Crawling: http://yutong-group.com/a/e_products/ (index: 49)
#
# Crawling: https://pacificbioproducts.com/ (index: 52)
#
# Crawling: https://www.marin-trust.com/sites/marintrust/files/2021-11/168%20Alimentos%20Marinos%20S.A.%20-%20Industrias%20Isla%20Quihua%20S.A%20Certificate.pdf (index: 53)
#
# Crawling: https://www.scoular.com/our-brands/encompass/ (index: 54)
#
# Crawling: https://www.svn.is/ (index: 55)
#
# Crawling: http://EMIS (index: 57)
# [ERROR] http://EMIS => Cannot connect to host emis:80 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://www.dsm.com/human-nutrition/en/products/nutritional-lipids.html (index: 60)
#
# Crawling: https://fishmealoil.com/ (index: 62)
#
# Crawling: https://www.biomarine.ie/ (index: 63)
#
# Crawling: http://www.icicleseafoods.com/ (index: 64)
# [ERROR] http://www.icicleseafoods.com/ =>
#
# Crawling: https://www.jaahdyttamo.fi/rehutuotanto (index: 69)
#
# Crawling: https://www.artemiacyst.com/Products/fishmeal/2021-12-14/36.html (index: 70)
#
# Crawling: http://www.lunarfreezing.co.uk/ (index: 71)
#
# Crawling: https://mbp.mu/ (index: 72)
#
# Crawling: https://akshafishmeal.com/ (index: 73)
# [ERROR] https://akshafishmeal.com/ =>
#
# Crawling: https://argopuroberkatindonesia.com/ (index: 74)
# [ERROR] https://argopuroberkatindonesia.com/ => Cannot connect to host argopuroberkatindonesia.com:443 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: http://wfekato.cn/?en.html (index: 75)
#
# Crawling: https://www.ett.fi/yleinen/matti-halme-oy-ettn-positiivilistalle/ (index: 77)
#
# Crawling: https://www.svn.is/ (index: 78)
#
# Crawling: https://www.linkedin.com/posts/bajamarinefoods_fishmeal-mexico-bajacalifornia-activity-7049199823136194560-Zxft/ (index: 79)
#
# Crawling: https://argopuroberkatindonesia.com/ (index: 81)
# [ERROR] https://argopuroberkatindonesia.com/ => Cannot connect to host argopuroberkatindonesia.com:443 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://californiabahiasmx.webnode.es/ (index: 82)
#
# Crawling: https://guaymasprotein.com.mx/?lang=es (index: 83)
#
# Crawling: https://www.dunsguide.com/es/company/1ec1cd5938f01adf23138b8166a7737a/industrial-pesquera-heras-sa-de-cv (index: 84)
#
# Crawling: https://mazinsa.com/ (index: 85)
# [ERROR] https://mazinsa.com/ => Cannot connect to host mazinsa.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1018)')]
#
# Crawling: https://www.google.ie/search?q=%22PESCAHARINA+DE+GUAYMAS%22+%22harina%22&sca_esv=6438a53135bfba51&ei=MI0GZ5-KGb-AhbIPy-zEoAU&ved=0ahUKEwif4v--u4GJAxU_QEEAHUs2EVQQ4dUDCA8&uact=5&oq=%22PESCAHARINA+DE+GUAYMAS%22+%22harina%22&gs_lp=Egxnd3Mtd2l6LXNlcnAiISJQRVNDQUhBUklOQSBERSBHVUFZTUFTIiAiaGFyaW5hIjIIECEYoAEYwwQyCBAhGKABGMMESIkRUFVYvA9wAXgAkAEAmAF-oAGDCaoBBDE1LjG4AQPIAQD4AQL4AQGYAgOgAugBmAMAiAYBkgcDMi4xoAfrHw&sclient=gws-wiz-serp (index: 87)
# [ERROR] https://www.google.ie/url?q=https://www.dnb.com/business-directory/company-information.seafood_product_preparation_and_packaging.mx.html&sa=U&ved=2ahUKEwidk4DcjOSKAxV0I0QIHRVLNGsQFnoECAUQAg&usg=AOvVaw3KgTojbJd5iyUkfmbNVOA3 =>
#
# Crawling: http://bohi.com.cn/en/About/index/id/488 (index: 89)
#
# Crawling: https://www.scotiagardenseafood.ca/fish/poultry-meal-yarmouth-nova-scotia-canada (index: 90)
#
# Crawling: https://pestell.com/products/feed-ingredients/proteins-meals/ (index: 91)
#
# Crawling: https://www.wcrl.com/finished-products (index: 92)
#
# Crawling: https://www.wcrl.com/finished-products (index: 93)
#
# Crawling: https://pelagia.com/cm/facilities/ (index: 94)
#
# Crawling: https://pelagia.com/cm/facilities/ (index: 95)
#
# Crawling: https://pelagia.com/cm/facilities/ (index: 96)
#
# Crawling: https://pelagia.com/cm/facilities/ (index: 97)
#
# Crawling: https://www.linkedin.com/in/eliat-cabrales-9b084272/?originalSubdomain=mx (index: 98)
#
# Crawling: https://www.manarthon.com/en/ (index: 99)
#
# Crawling: https://www.linkedin.com/in/alejandra-guerrero-espinoza-714487289/?originalSubdomain=mx (index: 100)
#
# Crawling: https://corporativo.selecta.com.mx/#products (index: 101)
# [ERROR] https://corporativo.selecta.com.mx/#products => Cannot connect to host corporativo.selecta.com.mx:443 ssl:True [SSLCertVerificationError: (1, "[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: Hostname mismatch, certificate is not valid for 'corporativo.selecta.com.mx'. (_ssl.c:1018)")]
#
# Crawling: http://www.Seapridellc.com (index: 102)
#
# Crawling: https://omegaprotein.com/contact-us/ (index: 103)
#
# Crawling: https://omegaprotein.com/contact-us/ (index: 104)
#
# Crawling: https://omegaprotein.com/ (index: 105)
#
# Crawling: https://pacificbioproducts.com/ (index: 106)
#
# Crawling: https://www.darlingii.com/en/solutions/feed (index: 107)
#
# Crawling: http://www.sth.is (index: 108)
#
# Crawling: http://www.xd-chem.com/ (index: 109)
#
# Crawling: https://www.darlingii.com/en/solutions/feed (index: 110)
#
# Crawling: https://aromanz.nz/ (index: 111)
#
# Crawling: https://www.shengyingaquatic.com/ (index: 112)
# [ERROR] https://www.shengyingaquatic.com/ => Cannot connect to host www.shengyingaquatic.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1018)')]
#
# Crawling: https://oceanaquaticproteins.com/contact-fish-meal.php (index: 113)
#
# Crawling: https://alphaasm.com/fr/ (index: 114)
#
# Crawling: https://mowinutrition.com/ (index: 115)
#
# Crawling: http://www.vsv.is (index: 116)
#
# Crawling: https://www.manarthon.com/en/products/our-fishmeal/ (index: 117)
#
# Crawling: https://eskja.is/en/products/ (index: 118)
#
# Crawling: https://www.laxa.is/ (index: 119)
#
# Crawling: https://www.mcfef.com/en/companies-ostrovnoi/ (index: 120)
#
# Crawling: https://www.mcfef.com/en/companies-ostrovnoi/ (index: 121)
#
# Crawling: https://isfelag.is/landvinnsla/ (index: 122)
#
# Crawling: https://www.ykrk.ru/en/company/#second__screen (index: 124)
#
# Crawling: http://www.lysi.is/ (index: 125)
#
# Crawling: https://www.ykrk.ru/en/company/#second__screen (index: 126)
#
# Crawling: https://ymrf.ru/ (index: 127)
#
# Crawling: https://bamrfish.com/ (index: 128)
#
# Crawling: https://salmonica.com/#!/tab/646359442-1 (index: 129)
#
# Crawling: https://www.ykrk.ru/ru/company/ (index: 130)
#
# Crawling: https://russianfishery.ru/en/ (index: 131)
#
# Crawling: https://www.scoular.com/our-brands/encompass/ (index: 133)
#
# Crawling: https://www.marineprotein.com.ec/en/productos (index: 135)
#
# Crawling: https://www.luckystarfeed.net/aboutus (index: 136)
#
# Crawling: https://www.importgenius.com/suppliers/sia-reneta (index: 137)
#
# Crawling: https://www.db.lv/zinas/puze-taps-42-miljonus-eiro-verta-zivju-miltu-rupnica-460570 (index: 138)
# [ERROR] https://www.db.lv/zinas/foto-gada-balvai-rigas-arhitektura-izvirzitie-objekti-tuvplana-latvijas-karoga-masts-ab-dambi-479338 =>
# [ERROR] https://www.db.lv/zinas/foto-gada-balvai-rigas-arhitektura-izvirzitie-objekti-tuvplana-mebelu-salons-ciekurkalna-467070 =>
#
# Crawling: https://www.biovast.lt/en/apie-mus/saldus/ (index: 139)
#
# Crawling: https://www.maruha-nichiro.com/
# https://www.sealord.com/ (index: 140)
#
# Crawling: https://kalifeks.lv/en/organic-fertilizer/#fishflour (index: 141)
#
# Crawling: https://www.linkedin.com/posts/fjell-technology-as_fishmeal-havexpo-amoffjell-activity-6930448507858223104-OvZp/?trk=public_profile_like_view (index: 142)
#
# Crawling: https://www.tridentseafoods.com/our-story/our-plants/ (index: 143)
#
# Crawling: https://argopuroberkatindonesia.com/ (index: 144)
# [ERROR] https://argopuroberkatindonesia.com/ => Cannot connect to host argopuroberkatindonesia.com:443 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://www.tridentseafoods.com/our-story/our-plants/ (index: 145)
#
# Crawling: https://www.unisea.com/products/ (index: 146)
#
# Crawling: http://www.argroup.com.br/ (index: 148)
#
# Crawling: http://www.argroup.com.br/ (index: 149)
#
# Crawling: https://seafood.media/agustiner/ (index: 151)
# [ERROR] https://seafood.media/ =>
#
# Crawling: https://www.westwardseafoods.com/ (index: 152)
#
# Crawling: http://nbfgroup.lv/#products (index: 153)
#
# Crawling: https://daybrook.com/ (index: 154)
#
# Crawling: http://airbuana.webs.com/ (index: 155)
# [ERROR] http://airbuana.webs.com/ => Cannot connect to host airbuana.webs.com:80 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://dhofarfisheries.com/ (index: 156)
#
# Crawling: https://company.lursoft.lv/en/venta-fm/41203027348 (index: 157)
#
# Crawling: https://trade-seafood.com/directory/seafood/processors/philbest-canning-ph.htm (index: 158)
#
# Crawling: http://www.lfg.com.cn/ (index: 159)
#
# Crawling: http://www.luhuabiomarine.com/ (index: 161)
#
# Crawling: https://nirsa.com/planta-de-harina-y-aceite-depescado/ (index: 162)
#
# Crawling: https://centurypacific.com.ph/about/ (index: 164)
#
# Crawling: https://www.biomar.com/ (index: 165)
#
# Crawling: https://megaprimefoods.com.ph/contact/ (index: 166)
#
# Crawling: https://www.havsbrun.fo/en/about/about-us/ (index: 167)
#
# Crawling: https://proexpacsa.com/ (index: 169)
#
# Crawling: https://corporate.allianceselectfoods.com/ (index: 170)
#
# Crawling: https://fiordoaustral.com/ (index: 171)
#
# Crawling: https://fiordoaustral.com/ (index: 172)
#
# Crawling: https://fiordoaustral.com/ (index: 173)
# [ERROR] https://fiordoaustral.com/wp-content/uploads/2022/12/SALMO-PET.pdf =>
#
# Crawling: https://fiordoaustral.com/ (index: 174)
#
# Crawling: https://fiordoaustral.com/ (index: 175)
#
# Crawling: https://fiordoaustral.com/ (index: 176)
#
# Crawling: https://fiordoaustral.com/ (index: 177)
#
# Crawling: http://www.qdkangjing.cn/en (index: 179)
#
# Crawling: https://ffskagen.dk/ (index: 182)
#
# Crawling: https://landes.cl/en/ (index: 183)
#
# Crawling: https://www.thaiunion.com/en/about/company/subsidiary/989/thai-union-marine-nutrients-gmbh (index: 186)
#
# Crawling: https://www.corpesca.cl/productos/ (index: 188)
# [ERROR] https://www.corpesca.cl/productos/ => Cannot connect to host www.corpesca.cl:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1018)')]
#
# Crawling: https://ablfoods.com.tr (index: 189)
#
# Crawling: https://www.corpesca.cl/productos/ (index: 190)
# [ERROR] https://www.corpesca.cl/productos/ => Cannot connect to host www.corpesca.cl:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1018)')]
#
# Crawling: https://daybrook.com/#products (index: 192)
#
# Crawling: https://www.linkedin.com/company/triogroup/about/ (index: 196)
#
# Crawling: https://www.multiproyectos.com.ec/page_spanish/product.html (index: 198)
#
# Crawling: https://argopuroberkatindonesia.com/ (index: 200)
# [ERROR] https://argopuroberkatindonesia.com/ => Cannot connect to host argopuroberkatindonesia.com:443 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://argopuroberkatindonesia.com/ (index: 201)
# [ERROR] https://argopuroberkatindonesia.com/ => Cannot connect to host argopuroberkatindonesia.com:443 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://indojayapratama.com/ (index: 202)
#
# Crawling: https://www.frozenb2b.com/supplier/iran-frozen-fish-frozen-seafood-22229/ (index: 203)
#
# Crawling: https://www.pesquerapolar.com/productos/ (index: 206)
#
# Crawling: https://stpbali.com/home/about (index: 208)
#
# Crawling: https://centurypacific.com.ph/ (index: 210)
#
# Crawling: https://www.universalcanning.com/ (index: 212)
#
# Crawling: https://sumberprotein.business.site/ (index: 216)
#
# Crawling: https://www.slord.com.ph/company.html (index: 218)
#
# Crawling: https://www.fksgroup.com/business-unit/fks-multi-agro/ (index: 219)
#
# Crawling: https://www.copacol.com.br/copacol (index: 220)
#
# Crawling: https://www.zcelcorp.com/about-4 (index: 221)
#
# Crawling: https://www.sahabatnelayanjayamandiri.com/about-us/ (index: 222)
#
# Crawling: https://www.permex.com.ph/ (index: 223)
#
# Crawling: https://www.coomarpes.com.ar/en/ (index: 224)
#
# Crawling: https://www.apoveira.pt/ (index: 226)
#
# Crawling: https://www.sarilautjaya.com/ (index: 227)
#
# Crawling: https://www.sumberyala.com/en/product/15/fish-meal-fish-oil (index: 228)
#
# Crawling: https://efp.pt/ (index: 229)
#
# Crawling: https://www.tobasurimi.com/companyprofile.html (index: 230)
# [ERROR] https://www.tobasurimi.com/gcg/005_prospektus.pdf =>
# [ERROR] https://www.tobasurimi.com/gcg/006_Laporan Keuangan Tahunan Audited PT Toba Surimi Industries Tbk 2019-2021.pdf =>
# [ERROR] https://www.tobasurimi.com/gcg/008_Laporan Keuangan CRAB Sept 2022.pdf =>
# [ERROR] https://www.tobasurimi.com/gcg/009_LKT_31Des2022.pdf =>
#
# Crawling: https://www.narcisodias.net/ (index: 235)
#
# Crawling: https://africaprotein.com/ (index: 238)
#
# Crawling: https://www.chinafeedonline.com.hk/sites/default/files/pdf/aqsiq_list/Mauritania_FM_20240329.pdf (index: 239)
# [ERROR] https://www.chinafeedonline.com.hk/sites/default/files/pdf/aqsiq_list/Mauritania_FM_20240329.pdf => Server disconnected
#
# Crawling: http://alfaserviceltd.com/en/presentation.html (index: 240)
#
# Crawling: https://web.archive.org/web/20190207011136/https://www.atyfen.com/ (index: 241)
# [ERROR] https://web.archive.org/web/20190207011136/https://www.atyfen.com/notre-entreprise/ =>
# [ERROR] https://web.archive.org/web/20190207011136/https://www.atyfen.com/moyenne-techniques/ =>
# [ERROR] https://web.archive.org/web/20190207011136/https://www.atyfen.com/moyenne-humaines/ =>
# [ERROR] https://web.archive.org/web/20190207011136/https://www.atyfen.com/certifications/ =>
# [ERROR] https://web.archive.org/web/20190207011136/https://www.atyfen.com/nos-produits/ =>
# [ERROR] https://web.archive.org/web/20190207011136/https://www.atyfen.com/huile-de-poisson/ =>
# [ERROR] https://web.archive.org/web/20190207011136/https://www.atyfen.com/huile-de-farine/ =>
# [ERROR] https://web.archive.org/web/20190207011136/https://www.atyfen.com/durabilite/ =>
# [ERROR] https://web.archive.org/web/20190207011136/https://www.atyfen.com/contact/ =>
# [ERROR] https://web.archive.org/web/20190207011136/https://www.atyfen.com/?s= =>
# [ERROR] https://web.archive.org/web/20190126072604/https://www.olark.com/site/2895-871-10-1097/contact =>
#
# Crawling: https://ejatlas.org/company/cofrima-proteine-sarl (index: 242)
#
# Crawling: https://www.reuters.com/article/world/us-politics/ocean-shock-fishmeal-factories-plunder-africa-idUSKCN1N420V/ (index: 244)
#
# Crawling: https://www.farofarine.com/production/ (index: 245)
# [ERROR] https://www.farofarine.com/production/ =>
#
# Crawling: http://www.fzhongdong.com/ (index: 246)
# [ERROR] http://www.fzhongdong.com/ =>
#
# Crawling: https://www.chinafeedonline.com.hk/sites/default/files/pdf/moa_list/Chinese%20License%2042%20%282018-05%29.pdf (index: 247)
# [ERROR] https://www.chinafeedonline.com.hk/sites/default/files/pdf/moa_list/Chinese%20License%2042%20%282018-05%29.pdf => Server disconnected
#
# Crawling: https://www.chinafeedonline.com.hk/sites/default/files/pdf/aqsiq_list/Mauritania_FM_20240329.pdf (index: 250)
# [ERROR] https://www.chinafeedonline.com.hk/sites/default/files/pdf/aqsiq_list/Mauritania_FM_20240329.pdf => Server disconnected
#
# Crawling: https://www.chinafeedonline.com.hk/sites/default/files/pdf/aqsiq_list/Mauritania_FM_20240329.pdf (index: 251)
# [ERROR] https://www.chinafeedonline.com.hk/sites/default/files/pdf/aqsiq_list/Mauritania_FM_20240329.pdf => Server disconnected
#
# Crawling: https://www.mahelturk.com/ (index: 256)
#
# Crawling: http://www.seafoodmr.com/en/ (index: 260)
# [ERROR] http://www.seafoodmr.com/en/ => Cannot connect to host www.seafoodmr.com:80 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://seafood.media/fis/companies/details.asp?l=e&filterby=companies&=&country_id=&page=1&company_id=164556 (index: 265)
# [ERROR] https://seafood.media/fis/companies/details.asp?l=e&filterby=companies&=&country_id=&page=1&company_id=164556 =>
#
# Crawling: https://ejatlas.org/company/mcf-sarl (index: 266)
#
# Crawling: https://europe.bloombiz.com/default.cgi/action/viewcompanies/companyid/830421/ (index: 268)
#
# Crawling: https://www.skretting.com/es-ec/ (index: 270)
#
# Crawling: https://www.gihonlab.com/en/naturales/productos-con-omega-3/ (index: 272)
#
# Crawling: https://servigrup.com.ec/en/by-products/ (index: 275)
# [ERROR] http://www.servigrup.com.ec/pelagics/ =>
# [ERROR] https://servigrup.com.ec/by-products =>
#
# Crawling: https://www.tradekey.com/product-free/Fish-Meal-fish-Oil-9396133.html (index: 277)
#
# Crawling: http://lucomercon.com/ (index: 279)
# [ERROR] http://lucomercon.com/ => Cannot connect to host lucomercon.com:80 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://www.productospesqueros.com/ (index: 282)
#
# Crawling: https://pbn.co.id/products (index: 285)
# [ERROR] https://pbn.co.id/products => Cannot connect to host pbn.co.id:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1018)')]
#
# Crawling: https://www.alimar.com.mx/CodigoEticaBARDA.pdf (index: 288)
#
# Crawling: https://exu.com.ec/ (index: 289)
#
# Crawling: https://www.globalsuppliersonline.com/supplier/Sgip-Complexe-Sa?id=525485&txtsrch=Yam&match= (index: 290)
#
# Crawling: https://www.fhgroupgh.com/the-fh-group (index: 291)
#
# Crawling: https://www.chinaafricasps.org/spsAdminCms/preview/sps/ueditor/jsp/upload/file/20240314/1710403031508010210.xlsx (index: 294)
#
# Crawling: https://www.chinaafricasps.org/spsAdminCms/preview/sps/ueditor/jsp/upload/file/20240314/1710403031508010210.xlsx (index: 295)
#
# Crawling: https://www.globalaginvesting.com/chinese-mauritanian-firms-form-150m-fishery-jv/ (index: 299)
#
# Crawling: https://www.chinaafricasps.org/spsAdminCms/preview/sps/ueditor/jsp/upload/file/20240314/1710403031508010210.xlsx (index: 301)
#
# Crawling: https://feed-pro.com//linea-de-consumo-animal/ (index: 302)
#
# Crawling: https://nirsa.com/planta-de-harina-y-aceite-depescado/ (index: 304)
#
# Crawling: https://seimarsa.com/ (index: 306)
#
# Crawling: https://apnord.ma/ (index: 307)
#
# Crawling: https://www.aquafeed.com/newsroom/news/argentina-puerto-madryn-plant-focuses-on-shrimp-oil/ (index: 314)
#
# Crawling: https://www.marin-trust.com/sites/marintrust/files/2023-08/PELIM_819942652_GenericCertificate_Final%20CIBEL%20II.pdf (index: 315)
#
# Crawling: http://www.austral.com.pe/es/plantas-flotas (index: 316)
#
# Crawling: https://www.charika.ma/societe-consortium-industriel-de-peche-30501 (index: 317)
#
# Crawling: http://www.austral.com.pe/es/plantas-flotas (index: 320)
#
# Crawling: http://www.austral.com.pe/es/plantas-flotas (index: 321)
#
# Crawling: http://www.austral.com.pe/es/plantas-flotas (index: 322)
#
# Crawling: http://www.austral.com.pe/es/plantas-flotas (index: 323)
#
# Crawling: http://www.urisaecuador.com/ (index: 324)
#
# Crawling: https://www.exalmar.com.pe/ / https://www.sanipes.gob.pe/habilitaciones_certificaciones/docs/LISTA_VIETNAM_CH_INDIRECTO.pdf (index: 325)
#
# Crawling: https://www.charika.ma/societe-eco-vert-prod-952434 (index: 326)
#
# Crawling: https://www.linkedin.com/in/grupo-varamar-fishmeal-936bb323b/?originalSubdomain=ec (index: 327)
#
# Crawling: https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=67141 (index: 328)
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=67141 =>
#
# Crawling: http://www.kakarikiproteins.co.nz/index.php?page=Home (index: 329)
#
# Crawling: http://www.gilcomes.com (index: 330)
#
# Crawling: https://www.intermarketinternational.com/ (index: 331)
#
# Crawling: https://nirsa.com/planta-de-harina-y-aceite-depescado/ (index: 332)
#
# Crawling: https://www.exalmar.com.pe/ (index: 335)
#
# Crawling: http://silver-food.com/en/qui-sommes-nous/profil/ (index: 338)
#
# Crawling: https://www.exalmar.com.pe/ / https://www.sanipes.gob.pe/habilitaciones_certificaciones/docs/LISTA_VIETNAM_CH_INDIRECTO.pdf (index: 339)
#
# Crawling: http://www.pcapricornio.com.pe (index: 340)
#
# Crawling: https://www.agromey.com.tr/yem.html (index: 344)
#
# Crawling: https://unimergroup.com/?lang=en (index: 345)
#
# Crawling: https://www.exalmar.com.pe/ / https://www.sanipes.gob.pe/habilitaciones_certificaciones/docs/LISTA_VIETNAM_CH_INDIRECTO.pdf (index: 347)
#
# Crawling: https://www.ayazimyem.com.tr (index: 348)
#
# Crawling: https://www.sanipes.gob.pe/habilitaciones_certificaciones/docs/LISTA_VIETNAM_CH_INDIRECTO.pdf (index: 349)
#
# Crawling: https://www.sanipes.gob.pe/habilitaciones_certificaciones/docs/CPHP_20150327.pdf (index: 351)
#
# Crawling: https://www.veritradecorp.com/es/peru/importaciones-y-exportaciones-inversiones-pesqueras-liguria-sac/ruc-20504968996 (index: 352)
#
# Crawling: https://www.donfernandosac.pe/quienessomos.php (index: 353)
#
# Crawling: https://quiaza.com/ (index: 354)
# [ERROR] http://www.inversionesquiaza.com/wp-content/uploads/2022/06/diagrama_como-vert.svg => Cannot connect to host www.inversionesquiaza.com:80 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://rosmei.com.ec/ (index: 355)
#
# Crawling: https://osf.pe/es/ (index: 356)
#
# Crawling: https://seafood.media/fis/companies/details.asp?l=e&company_id=92323 (index: 360)
# [ERROR] https://seafood.media/fis/companies/details.asp?l=e&company_id=92323 =>
#
# Crawling: https://springvalleyseafood.com/our-products/ (index: 361)
#
# Crawling: https://cdn.www.gob.pe/uploads/document/file/4572592/RD%201380-2023-PRODUCE-DS-PA.pdf (index: 362)
#
# Crawling: https://www.balnova.com/ (index: 363)
#
# Crawling: http://www.hofsethbiocare.no/ (index: 364)
#
# Crawling: https://www.gob.pe/institucion/produce/normas-legales/6035592-626-2024-produce-dgpchdi (index: 365)
#
# Crawling: https://www.sanipes.gob.pe/archivos/dhc/habilitaciones/docs/Establecimientos-registrados-para-exportar-Argentina-0921.pdf (index: 366)
#
# Crawling: https://baysunsuurunleri.com.tr (index: 368)
#
# Crawling: https://fortidex.com/ (index: 369)
# [ERROR] http://fac.fortidex.com/ =>
#
# Crawling: https://www.besyem.com.tr/ (index: 372)
#
# Crawling: https://kanpainternational.com/ (index: 374)
#
# Crawling: https://www.tfcsmart.com/demo/empresas/proteinas-del-ecuador-ecuaprotein-sa (index: 375)
#
# Crawling: https://fortidex.com/ (index: 376)
# [ERROR] http://fac.fortidex.com/ =>
#
# Crawling: https://fortidex.com/ (index: 377)
# [ERROR] http://fac.fortidex.com/ =>
#
# Crawling: https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=154658 (index: 378)
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=154658 =>
#
# Crawling: https://www.copeinca.com (index: 379)
#
# Crawling: https://cmmproducts.pe/ (index: 380)
#
# Crawling: https://web.archive.org/web/20230329200603/http://www.junsa.com.ec/index.html#inicio (index: 381)
# [ERROR] https://web.archive.org/web/20230329200603/https://webmail.junsa.com.ec/ =>
# [ERROR] https://web.archive.org/web/20230329200603/mision-y-vision.html =>
# [ERROR] https://web.archive.org/web/20230329200603/certificaciones.html =>
# [ERROR] https://web.archive.org/web/20230329200603/video-institucional.html =>
# [ERROR] https://web.archive.org/web/20230329200603/valores-corporativos.html =>
# [ERROR] https://web.archive.org/web/20230329200603/embarcaciones.html =>
#
# Crawling: https://www.fasa.ind.br/produtos/?lang=en (index: 383)
#
# Crawling: https://goedomega3.com/members/member/cia-pesquera-industrial-del-pacifico-s (index: 386)
#
# Crawling: https://www.maproteins.com/ (index: 389)
#
# Crawling: http://app02.sanipes.gob.pe:8089/Publico/Consulta_protocolos_plantas_excel (index: 391)
#
# Crawling: http://www.hirvati.com/fish-meal (index: 392)
# [ERROR] http://www.hirvati.com/fish-meal => Cannot connect to host www.hirvati.com:80 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://www.biomar.com/tr-tr (index: 393)
#
# Crawling: https://shamsi.industries/ (index: 394)
#
# Crawling: https://narcisodias.com/ (index: 396)
# [ERROR] https://narcisodias.com/ => Cannot connect to host narcisodias.com:443 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://anandagroup.com/ananda-enterprises.htm (index: 398)
# [ERROR] mailto://info@anandagroup.com => mailto://info@anandagroup.com
#
# Crawling: https://www.arbeeaquatic.com/, www.arbeefishoil.com (index: 400)
#
# Crawling: https://seafood.media/fis/companies/details.asp?l=s&company_id=51894 (index: 402)
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=51894 =>
#
# Crawling: https://www.mukkaproteins.com/about-mukka-proteins.php#gre (index: 403)
#
# Crawling: https://seafood.media/fis/companies/details.asp?l=s&company_id=51894 (index: 404)
# [ERROR] http://www.seafood.media =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=51894&submenu=categories =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=51894&submenu=cpp =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=67602 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=158516 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55224 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=158100 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=154658 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=148697 =>
# [ERROR] https://seafood.media/fis/worldnews/worldnews.asp?monthyear=&day=6&id=133152&l=s&special=0&ndb=0 =>
# [ERROR] https://seafood.media/fis/worldnews/worldnews.asp?monthyear=&day=6&id=133148&l=s&special=0&ndb=0 =>
# [ERROR] https://seafood.media/fis/worldnews/worldnews.asp?monthyear=&day=6&id=133147&l=s&special=0&ndb=0 =>
# [ERROR] https://seafood.media/fis/worldnews/worldnews.asp?monthyear=&day=6&id=133149&l=s&special=0&ndb=0 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=3 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=16 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=5255 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=5424 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=6199 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=10562 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=11929 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=17008 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=17221 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=17724 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=23097 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=23397 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=30967 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=31088 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=31259 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=32635 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=37681 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=42812 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=44778 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=45403 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=45733 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=46017 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=47092 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=47432 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=48048 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=49127 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=49459 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=50888 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=52571 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=53008 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=54410 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=54808 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55142 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55278 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55298 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55350 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55448 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55525 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=146700 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=147489 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=147732 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=151995 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=153342 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=153528 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=154597 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=154654 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=154902 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=155537 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=155766 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=156008 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=156284 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=156846 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=157135 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=158529 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=160670 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=161202 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=161652 =>
#
# Crawling: https://akshafishmeal.com/about.php (index: 405)
# [ERROR] https://akshafishmeal.com/about.php =>
#
# Crawling: https://seafood.media/fis/companies/details.asp?l=s&company_id=51894 (index: 406)
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=17724 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=23097 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=23397 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=30967 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=31088 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=31259 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=32635 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=37681 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=42812 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=44778 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=45403 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=45733 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=48048 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=49127 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=49459 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=53008 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=54410 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=54808 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55142 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55278 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55298 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55350 =>
#
# Crawling: https://www.bismiaquaticproducts.com/ (index: 408)
#
# Crawling: https://bismigroups.in/bismi-fisheries-pvt-ltd/ (index: 409)
#
# Crawling: https://www.gob.pe/institucion/produce/normas-legales/4222738-409-2023-produce-dgpchdi (index: 410)
#
# Crawling: https://seafood.media/fis/companies/details.asp?l=s&company_id=51894 (index: 411)
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=51894 =>
#
# Crawling: https://blueaquaproducts.com/ (index: 413)
# [ERROR] https://blueaquaproducts.com/ => Cannot connect to host blueaquaproducts.com:443 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://web.archive.org/web/20171013093717/http://khanfishmeal.webs.com/ (index: 415)
# [ERROR] https://web.archive.org/web/20171013093717/https://www.facebook.com/KhanTradersKarachi/ =>
# [ERROR] https://web.archive.org/web/20171013093717/http://khanfishmeal.tumblr.com/ =>
# [ERROR] https://web.archive.org/web/20210629110349/http://khanfishmeal.tumblr.com/ =>
#
# Crawling: https://prezi.com/p/ik_pnlpbqagw/eco-proyect-peru-sac/ (index: 416)
#
# Crawling: https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=154658 (index: 418)
# [ERROR] http://www.seafood.media =>
# [ERROR] https://seafood.media/fis/worldnews/index.asp?l=s =>
# [ERROR] https://seafood.media/fis/tradingmarket/index.asp?l=s =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=154658&submenu=info =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=154658&submenu=categories =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=154658&submenu=cpp =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=150351 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=51894 =>
# [ERROR] https://seafood.media/fis/worldnews/worldnews.asp?monthyear=&day=6&id=133152&l=s&special=0&ndb=0 =>
# [ERROR] https://seafood.media/fis/worldnews/worldnews.asp?monthyear=&day=6&id=133148&l=s&special=0&ndb=0 =>
# [ERROR] https://seafood.media/fis/worldnews/worldnews.asp?monthyear=&day=6&id=133147&l=s&special=0&ndb=0 =>
# [ERROR] https://seafood.media/fis/worldnews/worldnews.asp?monthyear=&day=6&id=133149&l=s&special=0&ndb=0 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=3 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=16 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=5255 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=5424 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=6199 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=10562 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=11929 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=17008 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=17221 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=17724 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=23097 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=23397 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=30967 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=31088 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=31259 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=32635 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=37681 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=42812 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=44778 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=45403 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=45733 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=46017 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=47092 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=47432 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=48048 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=49127 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=49459 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=50888 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=51894 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=52571 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=53008 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=54410 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=54808 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55142 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55278 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55298 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55350 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55448 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55525 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=55703 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=56961 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=58482 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=58823 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=61548 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=61884 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=67022 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=67808 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=69369 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=70088 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=70397 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=71617 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=72345 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=73659 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=76716 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=84693 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=87988 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=109319 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=120600 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=134652 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=135810 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=137331 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=142572 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=143836 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=146700 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=147489 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=147732 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=148697 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=151995 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=153342 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=153528 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=154597 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=154654 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=154902 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=155537 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=155766 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=156008 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=156284 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=156846 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=157135 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=158529 =>
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&company_id=160670 =>
# [ERROR] https://seafood.media/fis/tradingmarket/read.asp?sector=processing&id=420220&id_reply=420220&l=s =>
# [ERROR] https://seafood.media/fis/tradingmarket/read.asp?sector=processing&id=420124&id_reply=420124&l=s =>
# [ERROR] https://seafood.media/fis/tradingmarket/read.asp?sector=processing&id=420082&id_reply=420082&l=s =>
# [ERROR] https://seafood.media/fis/tradingmarket/read.asp?sector=processing&id=419923&id_reply=419923&l=s =>
# [ERROR] https://seafood.media/fis/tradingmarket/read.asp?sector=processing&id=419874&id_reply=419874&l=s =>
# [ERROR] https://seafood.media/fis/tradingmarket/read.asp?sector=processing&id=419811&id_reply=419811&l=s =>
# [ERROR] https://seafood.media/fis/tradingmarket/read.asp?sector=processing&id=419708&id_reply=419708&l=s =>
# [ERROR] https://seafood.media/fis/tradingmarket/read.asp?sector=processing&id=419698&id_reply=419698&l=s =>
# [ERROR] https://seafood.media/fis/tradingmarket/read.asp?sector=processing&id=419261&id_reply=419261&l=s =>
# [ERROR] https://seafood.media/fis/tradingmarket/read.asp?sector=processing&id=419188&id_reply=419188&l=s =>
#
# Crawling: https://www.ger.com.pe/ger.export/ga-ilo.html# (index: 419)
#
# Crawling: https://www.unitedmarineproducts.com/ (index: 420)
#
# Crawling: https://www.ger.com.pe/ger.export/ga-ilo.html# (index: 422)
#
# Crawling: https://www.sanipes.gob.pe/habilitaciones_certificaciones/docs/LISTA_VIETNAM_CH_INDIRECTO.pdf (index: 423)
#
# Crawling: http://www.cibelmaroc.com/en/ (index: 424)
#
# Crawling: https://www.sanipes.gob.pe/habilitaciones_certificaciones/docs/LISTA_VIETNAM_CH_INDIRECTO.pdf (index: 425)
#
# Crawling: https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=154658 (index: 426)
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=154658 =>
#
# Crawling: https://mob.datosperu.org/comercio-exterior-de-industrial-pesquera-santa-monica-sa-20205572229-en-la-partida-2301-pagina-6.php (index: 427)
#
# Crawling: https://repositorio.oefa.gob.pe/bitstream/handle/20.500.12788/210/Informe_N00250-2019-OEFA-DEAM-STEC.pdf?sequence=1&isAllowed=y (index: 428)
#
# Crawling: https://www.bluelinefoods.in/ (index: 429)
#
# Crawling: https://cdn.www.gob.pe/uploads/document/file/341604/Resoluci%C3%B3n_Directoral_N__05019-2019-PRODUCEDS-PA20190712-19467-tvowsz.pdf (index: 430)
#
# Crawling: https://www.coastalfisheries.com/, https://www.coastalexports.in/ (index: 431)
#
# Crawling: https://www.linkedin.com/in/luis-miguel-rodriguez-ramirez-93a66b40/?originalSubdomain=pe (index: 432)
#
# Crawling: https://www.veritradecorp.com/es/peru/importaciones-y-exportaciones-inversiones-pesqueras-liguria-sac/ruc-20504968996 (index: 434)
#
# Crawling: https://diamondfishesmeal.com/ (index: 435)
#
# Crawling: https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=154658 (index: 436)
# [ERROR] https://seafood.media/fis/companies/details.asp?l=s&filterby=companies&=&country_id=&page=1&company_id=154658 =>
#
# Crawling: https://www.iprisco.com.pe/harina.php (index: 437)
#
# Crawling: https://www.fahadfishmealoilco.com/ (index: 438)
#
# Crawling: https://www.sanipes.gob.pe/archivos/dhc/habilitaciones/docs/CPHP_20151119.pdf (index: 439)
#
# Crawling: https://www.copeinca.com (index: 440)
#
# Crawling: https://8013-pe.all.biz/harina-de-pescado-g37657 (index: 442)
#
# Crawling: https://www.copeinca.com (index: 443)
#
# Crawling: https://goedomega3.com/members/member/cia-pesquera-industrial-del-pacifico-s (index: 444)
#
# ...
#
# Crawling: https://www.biomar.com/ (index: 842)
#
# Crawling: https://www.auss.no/investments/industrial-holdings/foodcorp-chile-sa/ (index: 843)
#
# Crawling: https://www.goldenomega.cl/ (index: 845)
#
# Crawling: https://westpoint.co.za/ (index: 846)
#
# Crawling: https://ejatlas.org/company/africa-peche/?translate=it (index: 847)
#
# Crawling: https://naturmega.com/home (index: 848)
#
# Crawling: https://ejatlas.org/company/atlantic-peche (index: 849)
#
# Crawling: https://aman8368.en.ec21.com/company_info.html (index: 852)
#
# Crawling: https://www.facebook.com/www.nutrifish.com.pe (index: 853)
#
# Crawling: http://www.sanipes.gob.pe/habilitaciones_certificaciones/docs/LISTA_VIETNAM_CH_INDIRECTO.pdf (index: 854)
#
# Crawling: https://www.sanipes.gob.pe/archivos/dhc/habilitaciones/docs/Establecimientos-registrados-para-exportar-Argentina-0921.pdf (index: 856)
#
# Crawling: https://www.sanipes.gob.pe/habilitaciones_certificaciones/docs/LISTA_VIETNAM_CH_INDIRECTO.pdf (index: 857)
#
# Crawling: https://www.tradewheel.com/co/company-ahmed-elazzabi/products/ (index: 858)
#
# Crawling: https://www.sanipes.gob.pe/habilitaciones_certificaciones/docs/LISTA_VIETNAM_CH_INDIRECTO.pdf (index: 859)
#
# Crawling: https://levoalimentos.com.br/ (index: 860)
#
# Crawling: https://www.sanipes.gob.pe/habilitaciones_certificaciones/docs/LISTA_VIETNAM_CH_INDIRECTO.pdf (index: 861)
#
# Crawling: https://www.sanipes.gob.pe/habilitaciones_certificaciones/docs/CPHP_20150327.pdf (index: 862)
#
# Crawling: http://nutrivil.com.br/segmento/peixe/ (index: 866)
# [ERROR] http://nutrivil.com.br/site/wp-content/uploads/2015/08/catalogo-nutrivil-2015.pdf =>
#
# Crawling: https://patense.com.br/en/production-lines/ (index: 868)
#
# Crawling: https://www.chinaafricasps.org/spsAdminCms/preview/sps/ueditor/jsp/upload/file/20240314/1710403031508010210.xlsx (index: 872)
#
# Crawling: https://www.proteinmealtec.com.br/ (index: 874)
#
# Crawling: https://www.thaiunion.com/en/about/company/subsidiary/350/indian-ocean-tuna-limited (index: 875)
#
# Crawling: https://oceancos.com/ocean-protein (index: 877)
#
# Crawling: https://www.mn-feed.com/english/solution/#aqua-feed (index: 878)
#
# Crawling: https://unitedfishllc.com/ (index: 879)
#
# Crawling: https://www.biomar.com/ (index: 880)
#
# Crawling: https://pescave.es/en/home-2/ (index: 881)
#
# Crawling: https://industriasarpo.com/productos/ (index: 882)
# [PDF ERROR] PyCryptodome is required for AES algorithm
#
# Crawling: https://saria.es/areas-de-negocio/sarval/ (index: 883)
#
# Crawling: http://www.solutex.es/es/ (index: 884)
#
# Crawling: https://saria.es/areas-de-negocio/sarval/ (index: 885)
#
# Crawling: https://aterimar.com/harina-pescado/ (index: 886)
#
# Crawling: https://spaincap.org/downloads/anuario-SpainCap-2024.pdf (index: 887)
#
# Crawling: https://www.bioceval.de/en/ouroffering/fish-meal/ (index: 888)
#
# Crawling: https://www.seafood.media/fis/companies/details.asp?l=e&filterby=companies&company=Salmonoil&page=1&company_id=97929&country_id=cl (index: 889)
# [ERROR] https://www.seafood.media/fis/companies/details.asp?l=e&filterby=companies&company=Salmonoil&page=1&company_id=97929&country_id=cl =>
#
# Crawling: https://interfishmarket.com/es/company.aspx?id=5208; www.kbaholding.com (index: 890)
#
# Crawling: http://alfaserviceltd.com/en/presentation.html (index: 891)
#
# Crawling: http://www.mauritaniaseafoodsarl.com/ (index: 892)
# [ERROR] http://www.mauritaniaseafoodsarl.com/ => Cannot connect to host www.mauritaniaseafoodsarl.com:80 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://web.archive.org/web/20210417210455/http://cibelmaroc.com/ (index: 893)
#
# Crawling: https://ejatlas.org/company/atlantic-proteine (index: 894)
#
# Crawling: https://www.cevreadaleti.org/company/aussie-group-sarl (index: 895)
#
# Crawling: https://www.conresa.es/
# https://jealsa.com/ (index: 897)
#
# Crawling: http://www.fzhongdong.com/hwyyjd (index: 898)
# [ERROR] http://www.fzhongdong.com/hwyyjd =>
#
# Crawling: https://www.infojobs.net/harinas-de-andalucia-s.l./em-i98494948555851726582732015284371219156 (index: 899)
#
# Crawling: https://interfishmarket.com/en/company.aspx?id=79541 (index: 902)
#
# Crawling: https://www.peches.gov.mr/IMG/pdf/annexes1_pv1_mars_2018.pdf (index: 903)
# [ERROR] https://www.peches.gov.mr/IMG/pdf/annexes1_pv1_mars_2018.pdf => Cannot connect to host www.peches.gov.mr:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1018)')]
#
# Crawling: https://ejatlas.org/company/mmoa-peche-farine-et-huile (index: 905)
#
# Crawling: http://www.cmr2002.com (index: 906)
# [ERROR] http://www.cmr2002.com/download/business_profile.pdf =>
#
# Crawling: https://ejatlas.org/company/mouhit-al-baraka/?translate=ar (index: 910)
#
# Crawling: https://www.tridentseafoods.com/our-story/our-plants/ (index: 913)
#
# Crawling: https://tcf.co.th/en/ (index: 914)
# [ERROR] https://tcf.co.th/en/ =>
#
# Crawling: https://www.peches.gov.mr/IMG/pdf/liste_etablissements_agrees.pdf (index: 915)
# [ERROR] https://www.peches.gov.mr/IMG/pdf/liste_etablissements_agrees.pdf => Cannot connect to host www.peches.gov.mr:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1018)')]
#
# Crawling: https://ditp.sec.gouv.sn/sites/default/files/docs/Liste%20des%20%C3%A9tablissements%20agr%C3%A9%C3%A9s%20%C3%A0%20l%27exportation%20au%2031%20d%C3%A9cembre%202022%20.pdf (index: 917)
#
# Crawling: https://www.chotiwat.com/ (index: 918)
#
# Crawling: http://www.omega3.basf.com/ (index: 925)
#
# Crawling: http://www.pharmamarine.no/ (index: 928)
#
# Crawling: http://www.vesteraalens.no/ (index: 929)
#
# Crawling: https://www.oceana.co.za/ (index: 930)
#
# Crawling: https://luckystar.co.za/ (index: 931)
# [ERROR] https://luckystar.co.za/content/pdf/oceana-popia-policy.pdf =>
#
# Crawling: http://www.akb.co.kr/ (index: 932)
#
# Crawling: http://yormarine.com (index: 933)
#
# Crawling: https://www.biovast.lt/en/apie-mus/saldus/ (index: 934)
#
# Crawling: https://www.kantanggroup.com/ (index: 942)
#
# Crawling: http://www.huapla.com/ (index: 953)
#
# Crawling: https://www.thailuxe.com/ (index: 972)
#
# Crawling: https://www.malayanfishoil.com/Our_Products.html (index: 974)
#
# Crawling: https://mientayseafood.en.ec21.com/ (index: 975)
#
# Crawling: https://www.qlendau.com.my/home.html (index: 976)
#
# Crawling: http://botcatanlong.com/ (index: 978)
#
# Crawling: https://kr.kompass.com/c/hyundai-special-feed-ind-co-ltd/kr002214/ (index: 979)
#
# Crawling: https://ardmahikhazar.com/en/ (index: 980)
#
# Crawling: http://www.ipsademexico.com/index.html (index: 981)
#
# Crawling: https://longsinh.com.vn (index: 982)
#
# Crawling: https://masi.vn/about-kim-long (index: 983)
#
# Crawling: https://www.qlfishmeal.com/ (index: 984)
#
# Crawling: https://singvietfishmeal.com/ (index: 985)
#
# Crawling: https://mazinsa.com/ (index: 986)
# [ERROR] https://mazinsa.com/ => Cannot connect to host mazinsa.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1018)')]
#
# Crawling: https://pacificoindustrial.mx/#productos (index: 987)
#
# Crawling: https://www.sdkfishmeal.com/ (index: 988)
#
# Crawling: https://trisedco.com/m/en/ (index: 989)
#
# Crawling: https://kr.kompass.com/c/woojinfeed-ind-co-ltd/kr034725/ (index: 990)
#
# Crawling: https://www.lotaprotein.cl/ (index: 993)
# [ERROR] https://www.lotaprotein.cl/ => Cannot connect to host www.lotaprotein.cl:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1018)')]
#
# Crawling: https://www.pescachile.cl/ (index: 994)
# [ERROR] http://www.pescachile.cl/denuncias/ => Cannot connect to host www.pescachile.cldenuncias:443 ssl:default [nodename nor servname provided, or not known]
# [ERROR] http://www.pescachile.cl/pescachile-proveedores => Cannot connect to host www.pescachile.clpescachile-proveedores:443 ssl:default [nodename nor servname provided, or not known]
# [ERROR] https://www.pescachile.cl/denuncias/Manual de Conductas Pesca Chile.pdf =>
#
# Crawling: https://bahiacaldera.com/productos/ (index: 995)
#
# Crawling: https://fiordoaustral.com/productos/ (index: 996)
# [ERROR] https://fiordoaustral.com/wp-content/uploads/2022/12/SALMO-PET-PLUS.pdf =>
# [ERROR] https://fiordoaustral.com/wp-content/uploads/2022/12/HARINA-DE-MIX-SPECIES.pdf =>
# [ERROR] https://fiordoaustral.com/wp-content/uploads/2022/12/DEBONED-SALMON-MEAT.pdf =>
# [ERROR] http://fiordoaustral.com/wp-content/uploads/2022/11/Aminoterra.pdf =>
# [ERROR] http://fiordoaustral.com/wp-content/uploads/2022/11/Aminoroot.pdf =>
# [ERROR] http://fiordoaustral.com/wp-content/uploads/2022/11/Bioamino-L.pdf =>
# [ERROR] http://fiordoaustral.com/wp-content/uploads/2022/11/Bioil-S.pdf =>
#
# Crawling: http://suk-ruang-kaeo.com/home (index: 998)
# [ERROR] http://suk-ruang-kaeo.com/home => Cannot connect to host suk-ruang-kaeo.com:80 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: http://www.thaiunionfeedmill.com (index: 1004)
#
# Crawling: https://asianalliance.co.th/en/ (index: 1005)
#
# Crawling: https://www.nutritech.co.th/ (index: 1007)
#
# Crawling: http://www.tcunionagrotech.com/ (index: 1009)
#
# Crawling: https://petfood.symrise.com/ (index: 1011)
#
# Crawling: https://www.normfeed.com/en/home-page/ (index: 1012)
# [ERROR] https://www.normfeed.com/wp-content/gallery/NORMFEEDKATALOGEN.pdf =>
#
# Crawling: https://www.ozpekler.com.tr/ (index: 1013)
#
# Crawling: https://www.prometa.com.tr/home (index: 1014)
#
# Crawling: https://www.samsunbalikciliksuurunleri.com (index: 1015)
# [ERROR] https://www.samsunbalikciliksuurunleri.com => Cannot connect to host www.samsunbalikciliksuurunleri.com:443 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://www.samsunbalikciliksuurunleri.com/ (index: 1016)
# [ERROR] https://www.samsunbalikciliksuurunleri.com/ => Cannot connect to host www.samsunbalikciliksuurunleri.com:443 ssl:default [nodename nor servname provided, or not known]
#
# Crawling: https://www.serhancompany.com/ (index: 1017)
#
# Crawling: https://www.sibal.com.tr/ (index: 1018)
#
# Crawling: http://www.sibal.com.tr/index.php (index: 1019)
#
# Crawling: https://www.skretting.com/tr-TR/ (index: 1020)
# [ERROR] https://www.skretting.com/siteassets/global/documents/skretting-insight-lk-say.pdf?v=4b06c4 =>
#
# Crawling: https://sursanaqua.com/ (index: 1021)
#
# Crawling: https://sursanaqua.com/ (index: 1022)
#
# Crawling: https://sursanaqua.com/ (index: 1023)
#
# Crawling: https://sursanaqua.com/ (index: 1024)
#
# Crawling: https://sursanaqua.com/ (index: 1025)
#
# Crawling: https://sursanaqua.com/ (index: 1026)
#
# Crawling: https://luckyfish.co/contact (index: 1027)
#
# Crawling: https://www.linkedin.com/company/unifeed-su-urunleri/about/ (index: 1028)
#
# Crawling: https://www.setop.com/negocios.html# (index: 1029)
#
# Crawling: https://www.setop.com/negocios.html# (index: 1030)
#
# Crawling: https://omicrondephaa.com/es/ (index: 1032)
# [ERROR] https://omicrondephaa.com/es/ => Cannot connect to host omicrondephaa.com:443 ssl:default [None]
#
# Crawling: https://pelagia.com/cm/facilities/pelagia-protein/ (index: 1033)
#
# Crawling: https://www.guaymex.com/#x (index: 1034)
#
# Crawling: https://www.guaymex.com/#x (index: 1035)
#
# Crawling: https://guaymasprotein.com.mx/about-us/ (index: 1036)
#
# Crawling: http://www.nikko-yushi.co.jp/ (index: 1037)
#
# Crawling: https://www.goldenprize.co.th/ (index: 1039)
#
# Crawling: https://thaiunioningredients.com/ (index: 1047)
#
# Crawling: http://www.sirifeed.com/en/about (index: 1048)
#
# Crawling: https://www.kingfisher.co.th/Subsidiaries_SEAPAC.php (index: 1050)
#
# Crawling: https://www.spafoodgroup.com/ (index: 1061)
#
# Crawling: https://www.saomaisuperfeed.com/ (index: 1071)
#
# Crawling: https://www.vnfoods.vn/products/food-ingredients (index: 1073)
#
# Crawling: http://www.truongphucseafood.com (index: 1074)
#
# Crawling: https://mavin-group.com/en/animal-feed/aquafeed.html (index: 1080)
#
# Crawling: https://www.cpmalaysia.com/1/aquaculture-business/feedmills/ (index: 1083)
# [ERROR] http://www.cpmalaysia.com/1/wp-content/uploads/2023/06/policy.pdf => Cannot connect to host www.cpmalaysia.com:80 ssl:default [Connect call failed ('112.137.169.13', 80)]
# [ERROR] http://www.cpmalaysia.com/1/wp-content/uploads/2024/03/is.pdf => Cannot connect to host www.cpmalaysia.com:80 ssl:default [Connect call failed ('112.137.169.13', 80)]
# [ERROR] http://www.cpmalaysia.com/1/wp-content/uploads/2024/08/CPMY-IS-Policy_20240320.pdf => Cannot connect to host www.cpmalaysia.com:80 ssl:default [Connect call failed ('112.137.169.13', 80)]
# [ERROR] http://www.cpmalaysia.com/1/wp-content/uploads/2024/03/itms.pdf => Cannot connect to host www.cpmalaysia.com:80 ssl:default [Connect call failed ('112.137.169.13', 80)]
#
# Crawling: https://www.vnfoods.vn/products/food-ingredients (index: 1090)
#
# Crawling: https://www.naf-ye.com/AboutNAF/Details/6 (index: 1098)
#
# Crawling: https://ardmahikhazar.com/ (index: 1113)
# [ERROR] http://mailto@ardmahikhazar.com =>
#
# Crawling: http://www.faaltarin.com/web/babolsar (index: 1114)
#
# Crawling: https://behdanehshomal.com/en/about-us/ (index: 1115)
#
# Crawling: https://fanavarandarya.com/about-us/ (index: 1117)
#
# Crawling: http://www.kimiajask.com/ (index: 1121)
#
# Crawling: https://manaqua.com/about/ (index: 1123)
# [ERROR] https://manaqua.com/about/ =>
#
# Crawling: https://navidfeed.com/ (index: 1124)
# [ERROR] https://navidfeed.com/uploads/catalog.pdf =>
#
# Crawling: https://nazdanehsepahan.com/%d9%be%d9%88%d8%af%d8%b1-%d9%85%d8%a7%d9%87%db%8c/ (index: 1125)
#
# Crawling: https://neginfeed.com/en/ (index: 1126)
#
# Crawling: https://partsirang.com/en/home/ (index: 1127)
# [ERROR] https://partsirang.com/en/home/ =>
#
# Crawling: https://podremahi.ir/about-us/ (index: 1128)
#
# Crawling: https://podremahi.ir/about-us/ (index: 1129)
#
# Crawling: https://web.archive.org/web/20240401122335/http://www.mahikhoshk.com/ (index: 1130)
#
# Crawling: https://genopodr.ir/ (index: 1131)
# [ERROR] https://genopodr.ir/ =>
#
# Crawling: https://mshu-holdingtabaei.ir/en/about-our-process/ (index: 1132)
#
# Crawling: https://www.parskilka.com/ (index: 1133)
#
# Crawling: https://mahdaneco.ir/product/%F0%9F%90%A0-%D9%BE%D9%88%D8%AF%D8%B1-%D9%85%D8%A7%D9%87%DB%8C-%D8%AC%D9%86%D9%88%D8%A8#:~:text=%D8%A7%DB%8C%D9%86%20%D9%BE%D9%88%D8%AF%D8%B1%20%D8%AD%D8%A7%D9%88%DB%8C%20%D8%A7%D8%B3%DB%8C%D8%AF%D9%87%D8%A7%DB%8C%20%D8%A2%D9%85%DB%8C%D9%86%D9%87,%D9%88%20%D8%A7%D8%B3%D8%A8%20%D8%A7%D8%B3%D8%AA%D9%81%D8%A7%D8%AF%D9%87%20%D9%85%DB%8C%20%D8%B4%D9%88%D8%AF. (index: 1135)
#
# Crawling: https://inoti.com/iam/%D8%AE%D8%B1%DB%8C%D8%AF-%D9%BE%D9%88%D8%AF%D8%B1-%D9%85%D8%A7%D9%87%DB%8C (index: 1136)
#
# Crawling: https://mafanco.com/?fbclid=PAZXh0bgNhZW0CMTEAAaYbQfEBP6YLpC9AR0Mg69pg1_Lfyj6gfDO6Yh9LE-rUo2qh4NbTjyE-81o_aem_5qcvnOuk8CcuSUvqDdeViQ (index: 1138)
#
# Crawling: https://persianchabahar.com/ (index: 1142)
#
# Crawling: http://frabelle.com/group-of-companies/ (index: 1165)
#
# Crawling: https://www.ifc.com.pg/# (index: 1166)
#
# Crawling: https://www.southseastuna.com/ (index: 1167)
#
# Crawling: https://botcabien.wordpress.com/ (index: 1171)
#
# Crawling: https://www.olvea.com (index: 1172)
# [ERROR] https://www.olvea.com/wp-content/uploads/2020/10/OLVEAct-Now-Corporate-social-responsibility-Performance-report-2019-2020.pdf =>
#
# Crawling: https://www.oceanfishexport.com/copy-of-frozen-fish (index: 1173)
#
# Crawling: https://www.fhgroupgh.com/products-services (index: 1174)
#
# Crawling: https://www.aaaid.org/en/companies/arab-mauritanian-fish-company-samak/ (index: 1175)
#
# Crawling: http://tjmarine.in (index: 1176)
#
# Crawling: https://www.bawafishmealandoilco.com/ (index: 1177)
#
# Crawling: http://www.siddhivinayakfishmeal.com/ (index: 1179)
#
# Crawling: http://www.bawafishmeal.com (index: 1180)
#
# Crawling: http://mukkaseafoods.com (index: 1183)
#
# Crawling: https://fishmealoil.com/ (index: 1185)
#
# Crawling: http://www.goiatunaoil.com/ (index: 1186)
#
# Crawling: https://speed-fishmeal.com/fish-meal/ (index: 1187)
#
# Crawling complete. Elapsed time: 28854.58 seconds.
# Results saved to plants_updated.csv
